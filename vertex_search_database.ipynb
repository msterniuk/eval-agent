# %%
# !pip install PyPDF2

# %%
# !python load_and_chunk_documents.py --source_type gcs --source_path ca-sbox-es-aiml-demo-444 --folder_prefix Rag/ --output_folder ./data --chunk_size 1000
# Out:
# Found 2 PDF files in 'ca-sbox-es-aiml-demo-444/Rag/'
# Processing file: Rag/S&S_FS_OR_Fire Safety Management.pdf
# Processing file: Rag/SS_HS_ICP_TMT_Legionella.pdf
# Corpus has been saved at ./data/processed_corpus.csv

# %%
# !python generate_embeddings.py  --csv_path "./data/processed_corpus.csv" --project_id "ca-sbox-es-aiml-demo-444" --region "us-central1" --bucket_name "cloud-ai-platform-4292e48c-7499-4d31-8059-7ec80f0d493c"  --output_folder "./data"  --index_name "rag-index"  --deployed_index_id "rag_index"  --recreate_index
# Out:
# Generating embeddings for 2 chunks...
# Embeddings saved locally at: ./data/embeddings.json
# Uploaded to GCS: gs://cloud-ai-platform-4292e48c-7499-4d31-8059-7ec80f0d493c/batch_root
# gs://cloud-ai-platform-4292e48c-7499-4d31-8059-7ec80f0d493c/batch_root
# Checking for existing index and endpoint...
# Undeploying indexes from endpoint: rag-index-endpoint
# Undeploying index with ID: rag_index_20250415_1535
# Undeploying index MatchingEngineIndexEndpoint index_endpoint: projects/740246139241/locations/us-central1/indexEndpoints/56009122318909440
# Undeploy index MatchingEngineIndexEndpoint index_endpoint backing LRO: projects/740246139241/locations/us-central1/indexEndpoints/56009122318909440/operations/8449378076386656256
# MatchingEngineIndexEndpoint index_endpoint Undeployed index. Resource name: projects/740246139241/locations/us-central1/indexEndpoints/56009122318909440
# Deleting endpoint: rag-index-endpoint
# ...
